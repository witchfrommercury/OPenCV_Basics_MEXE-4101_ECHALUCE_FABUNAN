# %%
# !git clone https://github.com/witchfrommercury/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN.git
# %cd OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN # No indentation here
from IPython.display import clear_output
clear_output()

# %%
import numpy as np
import cv2

haar_cascade = 'haarcascade_car.xml'  # Path to Haar Cascade file
video = '/content/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN/Data Sets/Car Set 1.mp4'  # Path to the video file

# Open the video file
cap = cv2.VideoCapture(video)
car_cascade = cv2.CascadeClassifier(haar_cascade)

# Get the video's width, height, and frames per second (fps)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter('Car_Detector5.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w + 5, y + h + 5), (0, 0, 255), 3)

    # Write the processed frame to the video file
    out.write(frame)

# Release resources
cap.release()
out.release()

# %%
import numpy as np
import cv2

haar_cascade = 'haarcascade_car.xml'  # Path to Haar Cascade file
video = '/content/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN/Data Sets/Car Set 2.mp4'  # Path to the video file

# Open the video file
cap = cv2.VideoCapture(video)
car_cascade = cv2.CascadeClassifier(haar_cascade)

# Get the video's width, height, and frames per second (fps)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter('Car_Detector5.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w + 5, y + h + 5), (0, 0, 255), 3)

    # Write the processed frame to the video file
    out.write(frame)

# Release resources
cap.release()
out.release()

# %%
import numpy as np
import cv2

haar_cascade = 'haarcascade_car.xml'  # Path to Haar Cascade file
video = '/content/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN/Data Sets/Car Set 3.mp4'  # Path to the video file

# Open the video file
cap = cv2.VideoCapture(video)
car_cascade = cv2.CascadeClassifier(haar_cascade)

# Get the video's width, height, and frames per second (fps)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter('Car_Detector5.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w + 5, y + h + 5), (0, 0, 255), 3)

    # Write the processed frame to the video file
    out.write(frame)

# Release resources
cap.release()
out.release()

# %%
import numpy as np
import cv2

haar_cascade = 'haarcascade_car.xml'  # Path to Haar Cascade file
video = '/content/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN/Data Sets/Car Set 4.mp4'  # Path to the video file

# Open the video file
cap = cv2.VideoCapture(video)
car_cascade = cv2.CascadeClassifier(haar_cascade)

# Get the video's width, height, and frames per second (fps)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter('Car_Detector5.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w + 5, y + h + 5), (0, 0, 255), 3)

    # Write the processed frame to the video file
    out.write(frame)

# Release resources
cap.release()
out.release()

# %%
import numpy as np
import cv2

haar_cascade = 'haarcascade_car.xml'  # Path to Haar Cascade file
video = '/content/OPenCV_Basics_MEXE-4101_ECHALUCE_FABUNAN/Data Sets/Car Set 5.mp4'  # Path to the video file

# Open the video file
cap = cv2.VideoCapture(video)
car_cascade = cv2.CascadeClassifier(haar_cascade)

# Get the video's width, height, and frames per second (fps)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
out = cv2.VideoWriter('Car_Detector5.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w + 5, y + h + 5), (0, 0, 255), 3)

    # Write the processed frame to the video file
    out.write(frame)

# Release resources
cap.release()
out.release()
